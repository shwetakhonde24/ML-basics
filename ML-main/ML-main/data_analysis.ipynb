# %% [markdown]
# <a href="https://colab.research.google.com/github/sh-shrey/ML/blob/main/data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
df= pd.read_csv('/content/gdrive/MyDrive/final_analysis.csv')

# %%
df.head()
# Out:
#    gender  N1  N2  ...  tiredness  sleep_hour  Mood_prediction
# 0       1   1   5  ...          0           0                1
# 1       2   2   3  ...          0           0                0
# 2       2   5   1  ...          1           1                0
# 3       2   5   4  ...          1           1                0
# 4       2   3   3  ...          0           0                0
#
# [5 rows x 14 columns]

# %%
import numpy as np
import seaborn as sns
df.isnull().sum()
# Out:
# gender                   0
# N1                       0
# N2                       0
# N5                       0
# N6                       0
# N8                       0
# N9                       0
# N10                      0
# A9                       0
# C9                       0
# lack_of_concentration    0
# tiredness                0
# sleep_hour               0
# Mood_prediction          0
# dtype: int64

# %%
data = df.drop(['gender','lack_of_concentration','sleep_hour','tiredness'],axis=1)

# %%
#relationship analysis
corelation = data.corr()
sns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns,annot=True)

# %%
sns.pairplot(data)

# %%
sns.relplot(x='N1',y='N2',hue='Mood_prediction',data=df)

# %%
sns.displot(df['N1'],bins=5)

# %%
sns.catplot(x='N10',kind='box',data=df)
